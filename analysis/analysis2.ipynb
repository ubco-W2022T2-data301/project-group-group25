# %%
#My research question:

#Which lifestyle choices are responsible for high insurance costs? Are these decisions influenced by harmful stereotypes? Which groups (gender or age) are likely to be charged higher?

#Context:

#We can answer this question using specific forms of aggregated data to extract which characteristics yielded the highest insurance costs.

#Rough analysis plan:

#1.Data Cleaning: Remove unwanted, irrelevant, or repetitive data and fill in any missing information.
#2.Formatting: Adjust the data to be more comprehensive for our purposes and fix any formatting errors within the data set. This involves exploring what forms of data visualization tools would best suit something that involves comparisons; such as Box/Column charts.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from typing import TYPE_CHECKING
if TYPE_CHECKING:
    from .code import project_functions2
else:
    import sys
    sys.path.append("./code")
    import project_functions2

path = "../data/raw/insurance.csv"
df = project_functions2.load_and_process(path)
sns.countplot(x=df["Sex"])
#------------------------------------------------------------------------------------
#Previous work below:

    #df= (
        #pd.read_csv(r"C:\Users\somes\Downloads\project-group-group25\data\raw\insurance.csv")
        #.dropna()
        #.reset_index()
        #.rename(columns={"sex": "Sex"})
        #.rename(columns={"index": "Index"})
        #.rename(columns={"bmi": "BMI"})
        #.rename(columns={"children": "Number of Children"})
        #.rename(columns={"smoker": "Smoker?"})
        #.rename(columns={"region": "Area of Residence"})
        #.rename(columns={"charges": "Life Insurance Cost"})
        #.rename(columns={"age": "Age"})
    #)
#sns.countplot(x=df["Sex"])
#------------------------------------------------------------------------------------
#df=pd.read_csv(r"C:\Users\somes\Downloads\project-group-group25\data\raw\insurance.csv")
#df=df[df['age'].notna()]
#df=df[df['sex'].notna()]
#df=df[df['bmi'].notna()]
#df=df[df['smoker'].notna()]
#df=df[df['region'].notna()]
#df=df[df['charges'].notna()]
#df = df.reset_index()
#sns.countplot(x=df["sex"])

#When reviewing this chart, we can deduce hat there is no substantial difference between the amount of men and woman that were assesed for the data set. Based on this observation we can assure that our conclusions will not be biased towards one sex or another.
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from typing import TYPE_CHECKING
if TYPE_CHECKING:
    from .code import project_functions2
else:
    import sys
    sys.path.append("./code")
    import project_functions2

path = "../data/raw/insurance.csv"
df = project_functions2.load_and_process(path)
plot=sns.violinplot(data=df, y="Sex", x="Life Insurance Cost")
#------------------------------------------------------------------------------------
#Previous Work:


    #df= (
        #pd.read_csv(r"C:\Users\somes\Downloads\project-group-group25\data\raw\insurance.csv")
        #.dropna()
        #.reset_index()
        #.rename(columns={"sex": "Sex"})
        #.rename(columns={"index": "Index"})
        #.rename(columns={"bmi": "BMI"})
        #.rename(columns={"children": "Number of Children"})
        #.rename(columns={"smoker": "Smoker?"})
        #.rename(columns={"region": "Area of Residence"})
        #.rename(columns={"charges": "Life Insurance Cost"})
        #.rename(columns={"age": "Age"})
    #)
    
#plot=sns.violinplot(data=df, y="Sex", x="Life Insurance Cost")
#------------------------------------------------------------------------------------
#df=pd.read_csv(r"C:\Users\somes\Downloads\project-group-group25\data\raw\insurance.csv")
#df=df[df['age'].notna()]
#df=df[df['sex'].notna()]
#df=df[df['bmi'].notna()]
#df=df[df['smoker'].notna()]
#df=df[df['region'].notna()]
#df=df[df['charges'].notna()]
#df = df.reset_index()
#plot=sns.violinplot(data=df, y="sex", x="charges")

#Here we can deduce that men and women's cost distribution is similar which disproves any negative stereotypes which may suggest that one geneder is liklier to pursue a harmful lifestyle over the other.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from typing import TYPE_CHECKING
if TYPE_CHECKING:
    from .code import project_functions2
else:
    import sys
    sys.path.append("./code")
    import project_functions2

path = "../data/raw/insurance.csv"
df = project_functions2.load_and_process(path)

sns.jointplot(data=df, x="Life Insurance Cost", y="Age", kind="hex")
#------------------------------------------------------------------------------------
#Previous Work:

#df= (
   # pd.read_csv(r"C:\Users\somes\Downloads\project-group-group25\data\raw\insurance.csv")
    #.dropna()
    #.reset_index()
    #.rename(columns={"sex": "Sex"})
    #.rename(columns={"index": "Index"})
    #.rename(columns={"bmi": "BMI"})
    #.rename(columns={"children": "Number of Children"})
    #.rename(columns={"smoker": "Smoker?"})
    #.rename(columns={"region": "Area of Residence"})
    #.rename(columns={"charges": "Life Insurance Cost"})
    #.rename(columns={"age": "Age"})
#)

#sns.jointplot(data=df, x="Life Insurance Cost", y="Age", kind="hex")
#------------------------------------------------------------------------------------
#df=pd.read_csv(r"C:\Users\somes\Downloads\project-group-group25\data\raw\insurance.csv")
#df=df[df['age'].notna()]
#df=df[df['sex'].notna()]
#df=df[df['bmi'].notna()]
#df=df[df['smoker'].notna()]
#df=df[df['region'].notna()]
#df=df[df['charges'].notna()]
#df = df.reset_index()
#The following graph suggests that insurance prices tend to grow consistenelty as an indiviual ages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from typing import TYPE_CHECKING
if TYPE_CHECKING:
    from .code import project_functions2
else:
    import sys
    sys.path.append("./code")
    import project_functions2

path = "../data/raw/insurance.csv"
df = project_functions2.load_and_process(path)

sns.jointplot(data=df, x="Life Insurance Cost", y="BMI", kind="hex")
#------------------------------------------------------------------------------------
#Previous Work:

#df= (
    #pd.read_csv(r"C:\Users\somes\Downloads\project-group-group25\data\raw\insurance.csv")
    #.dropna()
    #.reset_index()
    #.rename(columns={"sex": "Sex"})
    #.rename(columns={"index": "Index"})
    #.rename(columns={"bmi": "BMI"})
    #.rename(columns={"children": "Number of Children"})
    #.rename(columns={"smoker": "Smoker?"})
    #.rename(columns={"region": "Area of Residence"})
    #.rename(columns={"charges": "Life Insurance Cost"})
    #.rename(columns={"age": "Age"})
#)

#sns.jointplot(data=df, x="Life Insurance Cost", y="BMI", kind="hex")
#------------------------------------------------------------------------------------
#df=pd.read_csv(r"C:\Users\somes\Downloads\project-group-group25\data\raw\insurance.csv")
#df=df[df['age'].notna()]
#df=df[df['sex'].notna()]
#df=df[df['bmi'].notna()]
#df=df[df['smoker'].notna()]
#df=df[df['region'].notna()]
#df=df[df['charges'].notna()]
#df = df.reset_index()
#From the following data we can tell that high BMI is much likelier to increase insurance prices than low BMI. And accordng to the data, the unhealthiest BMI seem to range from 30-45 and the most common seemed to be around the range of 30.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from typing import TYPE_CHECKING
if TYPE_CHECKING:
    from .code import project_functions2
else:
    import sys
    sys.path.append("./code")
    import project_functions2

path = "../data/raw/insurance.csv"
df = project_functions2.load_and_process(path)
    

pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
plot = sns.FacetGrid(df, row="Area of Residence", hue="Area of Residence", aspect=10, height=1, palette=pal)

plot.map(sns.kdeplot, "Life Insurance Cost",
      bw_adjust=.5, clip_on=False,
      fill=True, alpha=1, linewidth=1.5)
plot.map(sns.kdeplot, "Life Insurance Cost", clip_on=False, color="w", lw=2, bw_adjust=.5)

plot.refline(y=0, linewidth=2, linestyle="-", color=None, clip_on=False)

def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)

plot.map(label, "Life Insurance Cost")

plot.figure.subplots_adjust(hspace=-.1)

plot.set_titles("")
plot.set(yticks=[], ylabel="")
plot.despine(bottom=True, left=True)
#------------------------------------------------------------------------------------
#Previous Work:

#df= (
    #pd.read_csv(r"C:\Users\somes\Downloads\project-group-group25\data\raw\insurance.csv")
    #.dropna()
    #.reset_index()
    #.rename(columns={"sex": "Sex"})
    #.rename(columns={"index": "Index"})
    #.rename(columns={"bmi": "BMI"})
    #.rename(columns={"children": "Number of Children"})
    #.rename(columns={"smoker": "Smoker?"})
    #.rename(columns={"region": "Area of Residence"})
    #.rename(columns={"charges": "Life Insurance Cost"})
    #.rename(columns={"age": "Age"})
#)
    

#From the following graph we can deduce that people who live in the northeast region were far likelier to be charged higher for their insurance price while the northwest region was the least likeliest.
